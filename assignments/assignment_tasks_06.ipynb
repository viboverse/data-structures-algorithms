# %% [markdown]
# # Assignment 6
#
# These assignments are related to **Linked List**.
# * Read the related course material before doing the assignments from the [Linked list](https://dsa-material-6bd212.pages.labranet.jamk.fi/materials/06_linked_list/).
#
# General notes of assignments:
# * NOTE! In general, after the implementation of the function, all assignments have a test program for the function.
# * NOTE! Add your code in the assignments only after the TODO lines.

# %% [markdown]
# ## Assignment 6.1 (1 p)
#
# Implement new methods to `LinkedList` class.
#
# This Python code defines two classes: `Node` and `LinkedList`, implementing a basic **linked list** structure.
# * `Node` represents a node in the linked list and
# * `LinkedList` represents the linked list itself.
#
# In this assignment `LinkedList` implementation allows creating a linked list, add nodes, display the contents, and performing an iterative search for a specific value.
#
# Do the following task:
# * The `LinkedList` class will store the following integers: `3, 31, 21, 52, 16, 91, 10, and 5`. Insert these integers into the linked list.
# * Implement a search method called `iterative_search()` in the `LinkedList` class that takes the *Integer* to be searched for as an argument and reports whether this integer is found in the `LinkedList`.
# * Implement `search_items_from_list()`calling `iterative_search()` method from LinkedList class.
# * In test, you must add all items from `added_values` list to `linked_list`.

# %%
correct_answer_06_01 = [True, False, False, True]

import unittest

# Class for linkedlist node
class Node:
    def __init__(self, data=None, next_item=None):
        self.data = data
        self.next = next_item


# Class for linkedlist
class LinkedList:
    def __init__(self):
        self.head = None

    def add_node(self, data):
        new_node = Node(data)
        if self.head:
            current = self.head
            while current.next:
                current = current.next
            current.next = new_node
        else:
            self.head = new_node

    def display(self):
        current = self.head
        while current:
            print(current.data)
            current = current.next

    def iterative_search(self, n):
        # TODO: implement to search given value from the linked list.
        # TODO: return True if found, otherwise False
        current = self.head

        return False


def search_items_from_list(to_find, llist):
    # TODO: Implement this by calling iterative_search method from LinkedList class.
    results = []

    return results


# Test
added_values = [13, 31, 21, 52, 16, 91, 10, 5]
linked_list = LinkedList()

# TODO: Add all items from added_values to LinkedList.

linked_list.display()

search_items = [5, 32, 22, 13]

# Search given items from the LinkedList.
response_06_01 = search_items_from_list(search_items, linked_list)

try:
    unittest.TestCase().assertListEqual(response_06_01, correct_answer_06_01)
    print(f"Response {response_06_01} was correct.")
except AssertionError as err_msg:
    print(err_msg)
# Out:
# Lists differ: [] != [True, False, False, True]
#
# Second list contains 4 additional elements.
# First extra element 0:
# True
#
# - []
# + [True, False, False, True]

# %% [markdown]
# ## Assignment 6.2 (1 p)
#
# Sort linked list elements.
#
# Create a function called `ask_linked_list_from_user()` that prompts the user to input the number of nodes in the linked list.
# Subsequently, ask the user to enter the same number of strings to be saved into the linked list.
#
# Perform also the following operations:
# * Sort the order of the linked list using the bubble sort method. You must implement bubble sort in this assignment in `bubble_sort_for_linked_list()` function
# * Create a method that returns the content of the linked list as a `list`.

# %%
import unittest


class Node:
    def __init__(self, data=None, next_item=None):
        self.data = data
        self.next = next_item


# Class for linkedlist
class LinkedList:
    def __init__(self):
        self.head = None

    def add_node(self, data):
        new_node = Node(data)
        if self.head:
            current = self.head
            while current.next:
                current = current.next
            current.next = new_node
        else:
            self.head = new_node

    def display(self):
        current = self.head
        while current is not None:
            if current.data is not None:
                print(current.data)
            current = current.next

    def to_list(self):
        new_list = []
        current = self.head
        while current is not None:
            if current.data is not None:
                new_list.append(current.data)
            current = current.next
        return new_list

    def iterative_search(self, n):
        # TODO: implement to search value from the linked list.

        print(str(n) + " was not found from the list!")
        return False




def bubble_sort_for_linked_list(a):  # bubble sort
    #  TODO: Implement bubble sort to elements in the linked list.
    if a.head is None:
        return None

    pass


def ask_linked_list_from_user():
    # TODO: Ask the user for the number of nodes to enter the linked list.
    # TODO: Then ask the user to enter the same number of strings.
    llist = LinkedList()

    return llist


# Test
linked_list = ask_linked_list_from_user()
print(f"Original linked list: {linked_list.to_list()}")
correct_answer_06_02 = sorted(linked_list.to_list())

# Bubble sort for items in Linked List
bubble_sort_for_linked_list(linked_list)
response_06_02 = linked_list.to_list()

try:
    unittest.TestCase().assertNotEqual(response_06_02, [], "List should not be empty")
    unittest.TestCase().assertListEqual(response_06_02, correct_answer_06_02)
    print(f"Response {response_06_02} was correct.")
except AssertionError as err_msg:
    print(err_msg)
# Out:
# Original linked list: []
# [] == [] : List should not be empty

# %% [markdown]
# ## Assignment 6.3 (2p)
#
# Create **Double Linked List** that stores `Person` objects.
#
# In a Doubly linked list, each node contains a data element and two pointers, one referencing to the next node in the sequence and another referencing to the previous node.
# It allows for traversal in both directions, forward and backward, to perform operations such as insertion and deletion at both ends of the list.
#
# You should create the following methods in the `DoubleLinkedList` class:
# * `add_node()`: Add a new `Node` to Double linked list.
# * `Insert_at_the_beginning()`: Insert a new `Node` at the beginning of Double linked list.
# * `remove_node()`: Remove a `Node` from the Double linked list.

# %%
import unittest

correct_answer_06_03_str = "Jack, 61 <-> Bob, 45 <-> Anne, 40 <-> Jill, 38"

class Node:
    def __init__(self, data=None, next=None):
        self.prev = None
        self.data = data
        self.next = None


# Class for linkedlist
class DoubleLinkedList:
    def __init__(self):
        self.head = None

    def add_node(self, data):
        # TODO: Add new Node to Double linked list.

        self.display()

    def insert_at_the_beginning(self, data):
        # TODO: Insert new Node at the beginning of Double linked list.

        self.display()

    def remove_node(self, target):
        # TODO: Remove existing Node from the Double linked list.

        self.display()


    def display(self):
        current = self.head
        nodes = []
        print('\n')
        while current:
            nodes.append(str(current.data))
            current = current.next
        return ' <-> '.join(nodes)

    def to_string(self):
        current = self.head
        nodes = []
        while current:
            nodes.append(str(current.data))
            current = current.next
        return ' : '.join(nodes)


class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def name(self):
        return self.name

    def age(self):
        return self.age

    def __str__(self):
        return f"{self.name}, {self.age}"

    def __eq__(self, other):
        if not isinstance(other, Person):
            return NotImplemented

        return self.age == other.age and self.name == other.name


# Test
llist = DoubleLinkedList()

llist.add_node(Person("Jill", 37))
llist.add_node(Person("Bob", 45))
llist.add_node(Person("Jane", 29))
llist.add_node(Person("Anne", 40))
llist.insert_at_the_beginning(Person("Jack", 61))

# Two items are removed
print(llist.display())
llist.remove_node(Person("Jill", 37))
llist.remove_node(Person("Jane", 29))
print(llist.display())
llist.add_node(Person("Jill", 38))

response_06_03_str = llist.display()

try:
    unittest.TestCase().assertEqual(response_06_03_str, correct_answer_06_03_str)
    print(f"Response '{response_06_03_str}' was correct.")
except AssertionError as err_msg:
    print(err_msg)
# Out:
# '' != 'Jack, 61 <-> Bob, 45 <-> Anne, 40 <-> Jill, 38'
# + Jack, 61 <-> Bob, 45 <-> Anne, 40 <-> Jill, 38
